# %% [markdown]
# # NLTK Chatbot Training and Implementation

# %% [markdown]
# ### Scope of this chatbot
# We are going to build a chatbot using deep learning techniques using a **retrieval-based** approach. The chatbot will be trained on the dataset
# which contains conversation categories (intents), patterns, and responses. The model uses a Deep Neural Network with a single hidden layer to
# classify which category the input message belongs to and then the chatbot will select a random response from the list of responses, which have
# similar meaning.
#
# Topics the chatbot will be helpful with helping students finding answers to questions in the following topics:
# - Before calculus
# - Limits and continuity
# - Derivatives
# - Integrals
#
# Furthermore, this is just a prototype whose functionality can be greatly expanded in topics (other than math) it can reply to, depth of conversation, answer a
# plethra of questions and so on.

# %%
import random
import pathlib
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, Activation, Dropout
from keras.models import Sequential
import numpy as np
import pickle
import json
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %% [markdown]
# ### Download word packages for nltk_data

# %%
import nltk

nltk.data.path.append('./nltk_data/')

nltk.download('punkt', './nltk_data/')
nltk.download('wordnet', './nltk_data/')
nltk.download('omw-1.4', './nltk_data/')
# Out:
# [nltk_data] Downloading package punkt to ./nltk_data/...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to ./nltk_data/...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to ./nltk_data/...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
DIR_NAME = str(pathlib.Path().resolve())+'/'
nltk.data.path.append('./nltk_data/')

# %% [markdown]
# ## Intents (Input Data)

# %%
train = pd.read_json(DIR_NAME+'data/intents.json', orient='records')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   intents  21 non-null     object
# dtypes: object(1)
# memory usage: 296.0+ bytes

# %% [markdown]
# For each intent there is information on:
# - tag: Topic of conversation
# - patterns: The user input
# - responses: The chatbot's reply
# - context: A field that correlates to the tag field

# %% [markdown]
# ## Load json file

# %%
words = []
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open(DIR_NAME+'data/intents.json').read()
intents = json.loads(data_file)

 
for intent in intents['intents']:
    for pattern in intent['patterns']:

        tockenized_word_patterns = nltk.word_tokenize(pattern)
        words.extend(tockenized_word_patterns)
        documents.append((tockenized_word_patterns, intent['tag']))

        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ## Process words and classes

# %%
lemmatizer = WordNetLemmatizer()

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

# %%
pickle.dump(words, open(DIR_NAME + '/words.pkl', 'wb'))
pickle.dump(classes, open(DIR_NAME + '/classes.pkl', 'wb'))

# %% [markdown]
# ## Preprocessing

# %%
training = []

output_empty = [0] * len(classes)

for document in documents:
    bag = []

    tokenized_words = document[0]
    tokenized_words = [lemmatizer.lemmatize(word.lower()) for word in tokenized_words]

    for word in words:
        bag.append(1) if word in tokenized_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1

    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x_bags = list(training[:, 0])
train_y_output_rows = list(training[:, 1])
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Create a Deep Neural Network

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x_bags[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y_output_rows[0]), activation='softmax'))
# Out:
# 2023-06-09 13:51:31.033789: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd, metrics=['accuracy'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## Fit and save model

# %%
hist = model.fit(np.array(train_x_bags), np.array(train_y_output_rows), epochs=300, batch_size=10, verbose=1)
model.save('./chatbot_model/chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/300
# 10/10 [==============================] - 2s 5ms/step - loss: 3.0791 - accuracy: 0.0426
# Epoch 2/300
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0048 - accuracy: 0.0532
# Epoch 3/300
# 10/10 [==============================] - 0s 6ms/step - loss: 2.9588 - accuracy: 0.0745
# Epoch 4/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8909 - accuracy: 0.1277
# Epoch 5/300
# 10/10 [==============================] - 0s 5ms/step - loss: 2.8725 - accuracy: 0.1170
# Epoch 6/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7849 - accuracy: 0.2447
# Epoch 7/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7386 - accuracy: 0.1809
# Epoch 8/300
# 10/10 [==============================] - 0s 6ms/step - loss: 2.7173 - accuracy: 0.2660
# Epoch 9/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6216 - accuracy: 0.2660
# Epoch 10/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4768 - accuracy: 0.3404
# Epoch 11/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5097 - accuracy: 0.2766
# Epoch 12/300
# 10/10 [==============================] - 0s 5ms/step - loss: 2.4931 - accuracy: 0.3404
# Epoch 13/300
# 10/10 [==============================] - 0s 5ms/step - loss: 2.3742 - accuracy: 0.3298
# Epoch 14/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1494 - accuracy: 0.4574
# Epoch 15/300
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1132 - accuracy: 0.3936
# Epoch 16/300
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0629 - accuracy: 0.4468
# Epoch 17/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0238 - accuracy: 0.4468
# Epoch 18/300
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8698 - accuracy: 0.5319
# Epoch 19/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8146 - accuracy: 0.5213
# Epoch 20/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8321 - accuracy: 0.4894
# Epoch 21/300
# 10/10 [==============================] - 0s 5ms/step - loss: 1.6176 - accuracy: 0.5745
# Epoch 22/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6750 - accuracy: 0.5213
# Epoch 23/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5290 - accuracy: 0.6277
# Epoch 24/300
# 10/10 [==============================] - 0s 5ms/step - loss: 1.4939 - accuracy: 0.5638
# Epoch 25/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3504 - accuracy: 0.6596
# Epoch 26/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3225 - accuracy: 0.6489
# Epoch 27/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3964 - accuracy: 0.5638
# Epoch 28/300
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1557 - accuracy: 0.6596
# Epoch 29/300
# 10/10 [==============================] - 0s 10ms/step - loss: 1.2074 - accuracy: 0.6809
# Epoch 30/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2727 - accuracy: 0.6383
# Epoch 31/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1717 - accuracy: 0.6809
# Epoch 32/300
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1372 - accuracy: 0.7234
# Epoch 33/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0332 - accuracy: 0.6809
# Epoch 34/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9499 - accuracy: 0.7234
# Epoch 35/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9010 - accuracy: 0.7234
# Epoch 36/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8662 - accuracy: 0.7766
# Epoch 37/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7455 - accuracy: 0.7766
# Epoch 38/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8787 - accuracy: 0.7234
# Epoch 39/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7867 - accuracy: 0.8404
# Epoch 40/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7903 - accuracy: 0.7766
# Epoch 41/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7400 - accuracy: 0.7872
# Epoch 42/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6800 - accuracy: 0.8191
# Epoch 43/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7953 - accuracy: 0.7447
# Epoch 44/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5883 - accuracy: 0.8617
# Epoch 45/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5854 - accuracy: 0.8404
# Epoch 46/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6779 - accuracy: 0.8191
# Epoch 47/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7390 - accuracy: 0.7553
# Epoch 48/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7037 - accuracy: 0.7872
# Epoch 49/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6420 - accuracy: 0.7872
# Epoch 50/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5531 - accuracy: 0.8617
# Epoch 51/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4206 - accuracy: 0.8936
# Epoch 52/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5740 - accuracy: 0.8191
# Epoch 53/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.8936
# Epoch 54/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4995 - accuracy: 0.8085
# Epoch 55/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5259 - accuracy: 0.8298
# Epoch 56/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5810 - accuracy: 0.8085
# Epoch 57/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5464 - accuracy: 0.8191
# Epoch 58/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5151 - accuracy: 0.8298
# Epoch 59/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3927 - accuracy: 0.9043
# Epoch 60/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3360 - accuracy: 0.9255
# Epoch 61/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4866 - accuracy: 0.8298
# Epoch 62/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4223 - accuracy: 0.9043
# Epoch 63/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4155 - accuracy: 0.9043
# Epoch 64/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4907 - accuracy: 0.8830
# Epoch 65/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4297 - accuracy: 0.9149
# Epoch 66/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4295 - accuracy: 0.8617
# Epoch 67/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3838 - accuracy: 0.8723
# Epoch 68/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4323 - accuracy: 0.9149
# Epoch 69/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3549 - accuracy: 0.9149
# Epoch 70/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3575 - accuracy: 0.9255
# Epoch 71/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4093 - accuracy: 0.9468
# Epoch 72/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.8830
# Epoch 73/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3351 - accuracy: 0.9043
# Epoch 74/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3410 - accuracy: 0.8830
# Epoch 75/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2955 - accuracy: 0.9362
# Epoch 76/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3691 - accuracy: 0.9255
# Epoch 77/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3386 - accuracy: 0.8936
# Epoch 78/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3290 - accuracy: 0.9255
# Epoch 79/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2183 - accuracy: 0.9149
# Epoch 80/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3034 - accuracy: 0.9255
# Epoch 81/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2599 - accuracy: 0.9362
# Epoch 82/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3046 - accuracy: 0.9255
# Epoch 83/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.9149
# Epoch 84/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2034 - accuracy: 0.9574
# Epoch 85/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3160 - accuracy: 0.8830
# Epoch 86/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3019 - accuracy: 0.9043
# Epoch 87/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2671 - accuracy: 0.9255
# Epoch 88/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3318 - accuracy: 0.9043
# Epoch 89/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1862 - accuracy: 0.9574
# Epoch 90/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.9255
# Epoch 91/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2574 - accuracy: 0.9043
# Epoch 92/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2019 - accuracy: 0.9574
# Epoch 93/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3014 - accuracy: 0.8830
# Epoch 94/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2869 - accuracy: 0.9149
# Epoch 95/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2448 - accuracy: 0.9574
# Epoch 96/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 0.9362
# Epoch 97/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2679 - accuracy: 0.9043
# Epoch 98/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2824 - accuracy: 0.9043
# Epoch 99/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1784 - accuracy: 0.9681
# Epoch 100/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.9255
# Epoch 101/300
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1890 - accuracy: 0.9468
# Epoch 102/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2029 - accuracy: 0.9149
# Epoch 103/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2246 - accuracy: 0.9468
# Epoch 104/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1801 - accuracy: 0.9574
# Epoch 105/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2280 - accuracy: 0.9362
# Epoch 106/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2009 - accuracy: 0.9043
# Epoch 107/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1616 - accuracy: 0.9574
# Epoch 108/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 0.9362
# Epoch 109/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2242 - accuracy: 0.9468
# Epoch 110/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.9681
# Epoch 111/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1802 - accuracy: 0.9468
# Epoch 112/300
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2322 - accuracy: 0.9149
# Epoch 113/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2360 - accuracy: 0.9362
# Epoch 114/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2810 - accuracy: 0.8936
# Epoch 115/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1774 - accuracy: 0.9255
# Epoch 116/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1893 - accuracy: 0.9468
# Epoch 117/300
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1320 - accuracy: 0.9894
# Epoch 118/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2015 - accuracy: 0.9362
# Epoch 119/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1773 - accuracy: 0.9468
# Epoch 120/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1693 - accuracy: 0.9574
# Epoch 121/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9787
# Epoch 122/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1467 - accuracy: 0.9574
# Epoch 123/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1988 - accuracy: 0.9468
# Epoch 124/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2190 - accuracy: 0.9362
# Epoch 125/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9255
# Epoch 126/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2362 - accuracy: 0.9149
# Epoch 127/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1927 - accuracy: 0.9681
# Epoch 128/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1687 - accuracy: 0.9574
# Epoch 129/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1570 - accuracy: 0.9574
# Epoch 130/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1753 - accuracy: 0.9468
# Epoch 131/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2315 - accuracy: 0.9255
# Epoch 132/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2152 - accuracy: 0.9362
# Epoch 133/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2023 - accuracy: 0.9255
# Epoch 134/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1109 - accuracy: 0.9574
# Epoch 135/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1674 - accuracy: 0.9574
# Epoch 136/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1575 - accuracy: 0.9681
# Epoch 137/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.9787
# Epoch 138/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1466 - accuracy: 0.9574
# Epoch 139/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1631 - accuracy: 0.9574
# Epoch 140/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1846 - accuracy: 0.9468
# Epoch 141/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9468
# Epoch 142/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1551 - accuracy: 0.9681
# Epoch 143/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1871 - accuracy: 0.9255
# Epoch 144/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1313 - accuracy: 0.9574
# Epoch 145/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1515 - accuracy: 0.9574
# Epoch 146/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1279 - accuracy: 0.9468
# Epoch 147/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1387 - accuracy: 0.9681
# Epoch 148/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1544 - accuracy: 0.9787
# Epoch 149/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2054 - accuracy: 0.9362
# Epoch 150/300
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1142 - accuracy: 0.9362 0s - loss: 0.1311 - accuracy: 0.
# Epoch 151/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9468
# Epoch 152/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2166 - accuracy: 0.9468
# Epoch 153/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9255
# Epoch 154/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1353 - accuracy: 0.9787
# Epoch 155/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1910 - accuracy: 0.9255
# Epoch 156/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1594 - accuracy: 0.9574
# Epoch 157/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9681
# Epoch 158/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9574
# Epoch 159/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9681
# Epoch 160/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.9681
# Epoch 161/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9468
# Epoch 162/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.9681
# Epoch 163/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9894
# Epoch 164/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9574
# Epoch 165/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1383 - accuracy: 0.9574
# Epoch 166/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1468 - accuracy: 0.9681
# Epoch 167/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0747 - accuracy: 0.9787
# Epoch 168/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9894
# Epoch 169/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0924 - accuracy: 0.9894
# Epoch 170/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9787
# Epoch 171/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9681
# Epoch 172/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1679 - accuracy: 0.9362
# Epoch 173/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2067 - accuracy: 0.9362
# Epoch 174/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9894
# Epoch 175/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9787
# Epoch 176/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1098 - accuracy: 0.9787
# Epoch 177/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9681
# Epoch 178/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9787
# Epoch 179/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.9574
# Epoch 180/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.9574
# Epoch 181/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1352 - accuracy: 0.9681
# Epoch 182/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1218 - accuracy: 0.9681
# Epoch 183/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1607 - accuracy: 0.9362
# Epoch 184/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1356 - accuracy: 0.9468
# Epoch 185/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.9574
# Epoch 186/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1414 - accuracy: 0.9468
# Epoch 187/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9574
# Epoch 188/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1705 - accuracy: 0.9468
# Epoch 189/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 0.9574
# Epoch 190/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9149
# Epoch 191/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9681
# Epoch 192/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9681
# Epoch 193/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.9681
# Epoch 194/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9574
# Epoch 195/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0865 - accuracy: 0.9787
# Epoch 196/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9787
# Epoch 197/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2256 - accuracy: 0.9574
# Epoch 198/300
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0907 - accuracy: 0.9894
# Epoch 199/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9894
# Epoch 200/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0617 - accuracy: 0.9787
# Epoch 201/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0952 - accuracy: 0.9681
# Epoch 202/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1614 - accuracy: 0.9574
# Epoch 203/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9681
# Epoch 204/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.9787
# Epoch 205/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9468
# Epoch 206/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0920 - accuracy: 0.9681
# Epoch 207/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9787
# Epoch 208/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9787
# Epoch 209/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9894
# Epoch 210/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9787
# Epoch 211/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.9574
# Epoch 212/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1558 - accuracy: 0.9362
# Epoch 213/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9894
# Epoch 214/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9574
# Epoch 215/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.9787
# Epoch 216/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9574
# Epoch 217/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.9787
# Epoch 218/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9894
# Epoch 219/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0929 - accuracy: 0.9681
# Epoch 220/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.9681
# Epoch 221/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0566 - accuracy: 0.9894
# Epoch 222/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 0.9894
# Epoch 223/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9787
# Epoch 224/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.9787
# Epoch 225/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9787
# Epoch 226/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9787
# Epoch 227/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9681
# Epoch 228/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.9574
# Epoch 229/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.9574
# Epoch 230/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9681
# Epoch 231/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1126 - accuracy: 0.9681
# Epoch 232/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9894
# Epoch 233/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9681
# Epoch 234/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9681
# Epoch 235/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.9681
# Epoch 236/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9787
# Epoch 237/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9574
# Epoch 238/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9574
# Epoch 239/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.9681
# Epoch 240/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9787
# Epoch 241/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9574
# Epoch 242/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9787
# Epoch 243/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.9681
# Epoch 244/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9681
# Epoch 245/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1623 - accuracy: 0.9681
# Epoch 246/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9681
# Epoch 247/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 1.0000
# Epoch 248/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 249/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.9574
# Epoch 250/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9574
# Epoch 251/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 0.9681
# Epoch 252/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9894
# Epoch 253/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9468
# Epoch 254/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1138 - accuracy: 0.9787
# Epoch 255/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9787
# Epoch 256/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9574
# Epoch 257/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9574
# Epoch 258/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9894
# Epoch 259/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9681
# Epoch 260/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9787
# Epoch 261/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0635 - accuracy: 0.9894
# Epoch 262/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9787
# Epoch 263/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.9574
# Epoch 264/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9787
# Epoch 265/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9681
# Epoch 266/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1306 - accuracy: 0.9681
# Epoch 267/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9787
# Epoch 268/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9894
# Epoch 269/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.9787
# Epoch 270/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9894
# Epoch 271/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9681
# Epoch 272/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9681
# Epoch 273/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9894
# Epoch 274/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9681
# Epoch 275/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 0.9681
# Epoch 276/300
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0768 - accuracy: 0.9681
# Epoch 277/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9787
# Epoch 278/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0622 - accuracy: 0.9894
# Epoch 279/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 0.9681
# Epoch 280/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9894
# Epoch 281/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.9681
# Epoch 282/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9468
# Epoch 283/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9574
# Epoch 284/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9894
# Epoch 285/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9787
# Epoch 286/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9681
# Epoch 287/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9468
# Epoch 288/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9681
# Epoch 289/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 290/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9894
# Epoch 291/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9681
# Epoch 292/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0894 - accuracy: 0.9787
# Epoch 293/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0852 - accuracy: 0.9681
# Epoch 294/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.9681
# Epoch 295/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9681
# Epoch 296/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9787
# Epoch 297/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1244 - accuracy: 0.9574
# Epoch 298/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9787
# Epoch 299/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9894
# Epoch 300/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9681
# model created

# %% [markdown]
# ## Finally
# Use chatbot.py and run `python chatbot.py` to input a message and get a response!

# %%
from chatbot import chatbot_response

message1 = 'hello'
message2 = 'I need your help'
message3 = 'tell me about complex numbers'
message4 = 'is the power always true?'
message5 = 'can you please explain integral'
message6 = "That's helpful"

print(message1)
print(chatbot_response(message1))
print(message2)
print(chatbot_response(message2))
print(message3)
print(chatbot_response(message3))
print(message4)
print(chatbot_response(message4))
print(message5)
print(chatbot_response(message5))
print(message6)
print(chatbot_response(message6))
# Out:
# hello
# What's good? Ask me how can I help you?
# I need your help
# Here to offer you support. What integral or derivative rule do you need help with?
# tell me about complex numbers
# hmmm... this question is out of the scope of my expertise.
# is the power always true?
# Good question! The power rule is always true; even if the exponent is a fractionf, negative or even irrational
# can you please explain integral
# Think of the integtal as this: the derivative of the integral is the original function! Note that we are only talking about the indefinite integral
# That's helpful
# Any time!
